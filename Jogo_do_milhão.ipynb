# %% [markdown]
# <a href="https://colab.research.google.com/github/tottithome/Python/blob/main/Jogo_do_milh%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Funciona no replit

# %%
from os import system
from time import sleep
import random
from linecache import getline
continua = 1
pular = 3
pergunta_do_momento = 1

faceis_list = []
medias_list = []
dificeis_list = []
faceis_list_done = []
medias_list_done = []
dificeis_list_done = []


linha = linha.replace('\n','')
lista_user.append(linha.split(';'))

def menu():
  print('~'*50)
  print(f"\n{'✰ JOGO DO MIL ✰ ':^50}\n")
  print('~'*50)
  print('''
1 - Jogar
2 - Instruções
3 - Sair
  ''')
  print('~'*50)
  op = int(input('\nDigite a opção desejada: '))
  if op == 1:
    system('clear')
    prejogar()
  elif op == 2:
    system('clear')
    instrucoes()
  elif op == 3:
    menu_fim()
    continua == 0
  else:
    print('Opção inválida!')
    sleep(2)
    system('clear')
    menu()
def menu_fim():
  cont = 30
  system('clear')
  while cont >=0:
    system('clear')
    print("\n"*cont)
    print("-^"*30)
    print(f"\n{'🏆Você conseguiu atingir as dez fases!!!🏆':^50}\n")
    print("-^"*30)
    #print("\n"*cont)
    print(f"{'VOCÊ È O NOVO MILIONARIO, PARABÉNS!!':^50}")
    sleep(0.3)
    cont-=1
    print(f"{'Fim do jogo!!!👍':^50}")
def instrucoes():
  print('~'*50)
  print(f"\n{'INSTRUÇÕES':^50}\n")
  print('~'*50)
  print('''
  - Este jogo consiste em 10 rodadas, cada uma tem
quatro alternativas, onde apenas uma é a correta.
No início do jogo, o jogador tem 0 reais, podendo
chegar até os 1000(mil) reais,a cada rodada o
dinheiro do jogador aumenta, o jogo termina
quando o jogador erra uma pergunta, quando ele
erra, todo seu saldo é zerado.

  - É possível pular três rodadas, mas o saldo só
aumenta quando o jogador acerta uma pergunta.

  - Rodadas:

  1ª - 1 reais
  2ª - 5 reais
  3ª - 10 reais
  4ª - 50 reais
  5ª - 100 reais
  6ª - 200 reais
  7ª - 300 reais
  8ª - 400 reais
  9ª - 500 reais
  10ª - 1.000 reais\n''')
  if input('envie qualquer coisa para voltar ao menu: ') != "§" :
    system('clear')
    menu()
def prejogar():
  system('clear')
  print('~'*50)
  print(f"\n{'pronto para começar?':^50}\n")
  print('~'*50)
  if input('\nDigite qualquer coisa para começar: ') != "§" :
    jogar()
def jogar():
  system('clear')
  with open("dificeis.txt") as dificeis:
      for line in dificeis:
        dificeis_list.append(line)
  with open("medias.txt") as medias:
      for line in medias:
        medias_list.append(line)
  with open("faceis.txt") as faceis:
      for line in faceis:
        faceis_list.append(line)
  for x in range(1,4):
    print(f"{x}º PERGUNTA":^30)
    with open("faceis.txt") as faceis:
      for line in faceis:
          faceis_list.append(line)
  for y in range(4,8):
    print(f"{y}o PERGUNTA":^30)
    with open("medias.txt") as medias:
      for line in medias:
          medias_list.append(line)
  for z in range(8,11):
    print(f"{z}o PERGUNTA":^30)
    with open("dificeis.txt") as dificeis:
      for line in dificeis:
          dificeis_list.append(line)
  print('~'*50)




  while True:
    question = random.choice(faceis_list)
    nquestion = faceis_list.index(question)
    faceis_list.pop(nquestion)
    faceis_list_done.append(question)
    print(question)
    input("Digite    ")

def pula():
  system('clear')
  global pular
  if input('deseja pular? (s/n)').lower() == 's' :
    pular -= 1
  elif pular == n :
    print('ok')
  elif pular == 0:
    print("Você não pode pular mais! responda ou pare de jogar.")
while continua == 1:
  menu()
  break

# %% [markdown]
# Faceis
# Qual é a capital da França?;Berlim;Roma;Londres;Paris; d
# Qual é o símbolo químico do ouro?;Ou;Au;Fe;Cu; b
# Quem escreveu "Romeu e Julieta"?;Charles Dickens;Jane Austen;WilliamShakespeare;F. Scott Fitzgerald; c
# Qual é o planeta mais próximo do Sol?;Vênus;Marte;Mercúrio;Júpiter; c
# Qual é a capital do Brasil?; Brasília; São Paulo; Bahia; Rio de Janeiro; a
# Quem escreveu "Dom Quixote"?; William Shakespeare; Fyodor Dostoevsky; Miguel de Cervantes; Jane Austen; c
# Qual é o maior planeta do sistema solar?; Marte; Júpiter; Saturno; Vênus; b
# Quantos continentes existem no mundo?; 5; 6; 7; 8; c
#
# Medias
# Qual é o segundo planeta a partir do Sol?;Marte;Vênus;Mercúrio;Júpiter; b
# Quem é o autor da Mona Lisa?;Vincent van Gogh;Pablo Picasso;Leonardo da Vinci;Michelangelo; c
# Qual é o país mais populoso da África?;Nigéria;Etiópia;Egito;África do Sul; a
# Qual é a capital da Austrália?;Melbourne;Sydney;Perth;Camberra; d
# Quem foi o primeiro presidente dos Estados Unidos?; George Washington; Thomas Jefferson; Abraham Lincoln; Benjamin Franklin; a
# Qual é a fórmula química da água?; CO2; H2O; NaCl; H2O2; b
# Qual é o segundo maior país do mundo em termos de área?; Estados Unidos; China; Canadá; Brasil;c
# Quem é o autor da pintura "A Última Ceia"?; Michelangelo; Vincent van Gogh; Leonardo da Vinci; Pablo Picasso; c
# Quem escreveu "Dom Quixote"?;Miguel de Cervantes;William Shakespeare;Charles Dickens;Jane Austen; a
# Quem foi o primeiro presidente do Brasil?;Getúlio Vargas;Juscelino Kubitschek;Marechal Deodoro;Tancredo Neves; c
# Qual é o elemento químico mais abundante na crosta terrestre?;Silício;Oxigênio;Ferro;Carbono; a
#
# Dificeis
# Qual é o nome do quarto maior satélite natural de Júpiter?; Io; Europa; Calisto; Ganimedes; d
# Quem foi o físico teórico responsável pela formulação das equações que descrevem o eletromagnetismo?;Albert Einstein ;Isaac Newton; Galileu Galilei; James Clerk Maxwell; d
# Qual é o ácido presente no estômago humano que ajuda na digestão dos alimentos?; Ácido cítrico; Ácido clorídrico; Ácido sulfúrico; Ácido acético; b
# Qual é a capital do Butão?; Katmandu; Dacar; Timbu; dzonga; c
# Qual é o valor de π (pi) com cinco casas decimais?; 3.14159; 3.14152; 3.14015; 3.15142; a
# Quem é a primeira mulher a viajar para o espaço?; Valentina Tereshkova; Sally Ride; Mae Jemison; Yuri Gagarin; a
# Qual é o único planeta do sistema solar que gira no sentido horário?; Vênus; Marte; Urano; Júpiter; c
# Quem é o autor de "Crime e Castigo"?; Leo Tolstoy; Fyodor Dostoevsky; Franz Kafka; Victor Hugo; b
